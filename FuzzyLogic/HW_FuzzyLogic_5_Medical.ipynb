# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhtruongphan/HomeworkAI/blob/main/HW_FuzzyLogic_5_Medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Họ tên sinh viên : Phan Thanh Trường**
# ## **Mã số sinh viên : 19146293**
# ## **Bài tập về nhà Fuzzylogic - Medical**

# %%
# !pip install scikit-fuzzy
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as  ctrl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=8c47d3c30a70546a7aec8c817d723a4de0a3ffc6d0458b4d15bbcc1a0ee5a903
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %% [markdown]
# # **Part 1**

# %%
fever=ctrl.Antecedent(np.arange(0,0.9,0.1),'Fever')
headache=ctrl.Antecedent(np.arange(0,0.9,0.1),'Headache')
nausea=ctrl.Antecedent(np.arange(0,0.9,0.1),'Nausea')
vomiting=ctrl.Antecedent(np.arange(0,0.9,0.1),'Vomiting')

out1=ctrl.Consequent(np.arange(0,0.9,0.1),'Out1')

ijaundice=ctrl.Antecedent(np.arange(0,0.9,0.1),'Ijaundice')
enlarge_liver=ctrl.Antecedent(np.arange(0,0.9,0.1),'Enlarge_liver')
joint_pain=ctrl.Antecedent(np.arange(0,0.9,0.1),'Joint_pain')
body_weakness=ctrl.Antecedent(np.arange(0,0.9,0.1),'Body_weakness')

out2=ctrl.Consequent(np.arange(0,0.9,0.1),'Out2')

dizziness=ctrl.Antecedent(np.arange(0,0.9,0.1),'Dizziness')
loss_of_appetite=ctrl.Antecedent(np.arange(0,0.9,0.1),'Loss_of_appetite')
mp=ctrl.Antecedent(np.arange(0,0.9,0.1),'Mp')

out3=ctrl.Consequent(np.arange(0,0.9,0.1),'Out3')

conclu=ctrl.Consequent(np.arange(0,0.9,0.1),'Conclu')

fever['Mild']=fuzz.trimf(fever.universe,[0 ,0.15, 0.3])
fever['Moderate']=fuzz.trimf(fever.universe,[ 0.3, 0.45, 0.6])
fever['Severe']=fuzz.trimf(fever.universe,[0.6, 0.7 ,0.8 ])

headache['Mild']=fuzz.trimf(headache.universe,[0 ,0.15, 0.3])
headache['Moderate']=fuzz.trimf(headache.universe,[ 0.3 ,0.45, 0.6])
headache['Severe']=fuzz.trimf(headache.universe,[0.6 ,0.7 ,0.8 ])

nausea['Mild']=fuzz.trimf(nausea.universe,[0 ,0.15 ,0.3])
nausea['Moderate']=fuzz.trimf(nausea.universe,[ 0.3, 0.45, 0.6])
nausea['Severe']=fuzz.trimf(nausea.universe,[0.6 ,0.7 ,0.8 ])

vomiting['Mild']=fuzz.trimf(vomiting.universe,[0 ,0.15 ,0.3])
vomiting['Moderate']=fuzz.trimf(vomiting.universe,[ 0.3, 0.45, 0.6])
vomiting['Severe']=fuzz.trimf(vomiting.universe,[0.6 ,0.7 ,0.8 ])

ijaundice['Mild']=fuzz.trimf(ijaundice.universe,[0 ,0.15 ,0.3])
ijaundice['Moderate']=fuzz.trimf(ijaundice.universe,[ 0.3 ,0.45, 0.6])
ijaundice['Severe']=fuzz.trimf(ijaundice.universe,[0.6 ,0.7 ,0.8 ])

enlarge_liver['Mild']=fuzz.trimf(enlarge_liver.universe,[0, 0.15 ,0.3])
enlarge_liver['Moderate']=fuzz.trimf(enlarge_liver.universe,[ 0.3, 0.45, 0.6])
enlarge_liver['Severe']=fuzz.trimf(enlarge_liver.universe,[0.6 ,0.7 ,0.8 ])

joint_pain['Mild']=fuzz.trimf(joint_pain.universe,[0 ,0.15 ,0.3])
joint_pain['Moderate']=fuzz.trimf(joint_pain.universe,[ 0.3, 0.45, 0.6])
joint_pain['Severe']=fuzz.trimf(joint_pain.universe,[0.6 ,0.7 ,0.8 ])

body_weakness['Mild']=fuzz.trimf(body_weakness.universe,[0 ,0.15, 0.3])
body_weakness['Moderate']=fuzz.trimf(body_weakness.universe,[ 0.3, 0.45, 0.6])
body_weakness['Severe']=fuzz.trimf(body_weakness.universe,[0.6 ,0.7 ,0.8 ])

dizziness['Mild']=fuzz.trimf(dizziness.universe,[0, 0.15 ,0.3])
dizziness['Moderate']=fuzz.trimf(dizziness.universe,[ 0.3, 0.45, 0.6])
dizziness['Severe']=fuzz.trimf(dizziness.universe,[0.6, 0.7 ,0.8 ])

loss_of_appetite['Mild']=fuzz.trimf(loss_of_appetite.universe,[0 ,0.15, 0.3])
loss_of_appetite['Moderate']=fuzz.trimf(loss_of_appetite.universe,[ 0.3, 0.45, 0.6])
loss_of_appetite['Severe']=fuzz.trimf(loss_of_appetite.universe,[0.6 ,0.7 ,0.8 ])

mp['Mild']=fuzz.trimf(mp.universe,[0 ,0.15, 0.3])
mp['Moderate']=fuzz.trimf(mp.universe,[ 0.3, 0.45, 0.6])
mp['Severe']=fuzz.trimf(mp.universe,[0.6 ,0.7 ,0.8 ])

out1['Mild']=fuzz.trimf(out1.universe,[0 ,0.15, 0.3])
out1['Moderate']=fuzz.trimf(out1.universe,[ 0.3, 0.45, 0.6])
out1['Severe']=fuzz.trimf(out1.universe,[0.6, 0.7 ,0.8 ])

out2['Mild']=fuzz.trimf(out2.universe,[0 ,0.15, 0.3])
out2['Moderate']=fuzz.trimf(out2.universe,[ 0.3, 0.45, 0.6])
out2['Severe']=fuzz.trimf(out2.universe,[0.6, 0.7 ,0.8 ])

out3['Mild']=fuzz.trimf(out3.universe,[0 ,0.15, 0.3])
out3['Moderate']=fuzz.trimf(out3.universe,[ 0.3, 0.45, 0.6])
out3['Severe']=fuzz.trimf(out3.universe,[0.6, 0.7 ,0.8 ])

conclu['Mild']=fuzz.trimf(conclu.universe,[0 ,0.15, 0.3])
conclu['Moderate']=fuzz.trimf(conclu.universe,[ 0.3, 0.45, 0.6])
conclu['Severe']=fuzz.trimf(conclu.universe,[0.6, 0.7 ,0.8 ])

fever.view()
headache.view()
nausea.view()
vomiting.view()
ijaundice.view()
enlarge_liver.view()
joint_pain.view()
body_weakness.view()
dizziness.view()
loss_of_appetite.view()
mp.view()
conclu.view()

# %%
# concluing_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48,rule49,rule50,rule51,rule52,rule53,rule54])
# concluing = ctrl.ControlSystemSimulation(concluing_ctrl)
# concluing.input['fever'] = 0.4
# concluing.input['headache'] = 0.2
# concluing.input['nausea'] = 0.8
# concluing.input['vomiting'] = 0.5
# concluing.compute()
# print(concluing.output['conclu'])
# conclu.view(sim=concluing)

# %% [markdown]
# # **Part 2 - Rules 1**

# %%
rule1 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Mild'])
rule2 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Mild'])
rule3 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Mild'])

rule4 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])
rule5 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])
rule6 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])

rule7 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule8 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule9 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule10 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])
rule11 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])
rule12 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])

rule13 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Mild'])
rule14 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Mild'])
rule15 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Mild'])

rule16 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Mild'])
rule17 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Mild'])
rule18 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Mild'])

rule19 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Mild'])
rule20= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Mild'])
rule21 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Mild'])

rule22 = ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Mild'])
rule23= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Mild'])
rule24= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Mild'])

rule25= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Mild'])
rule26= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Mild'])
rule27= ctrl.Rule(fever['Mild']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Mild'])
rule28= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Mild'])
rule29= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Mild'])
rule30= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Mild'])

rule31= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])
rule32= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])
rule33= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Mild'])

rule34= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule35= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule36= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Mild'])
rule37= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])
rule38= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])
rule39= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Mild'])

rule40= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule41= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule42= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])

rule43= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule44= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule45= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])

rule46= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule47= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule48= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])

rule49 = ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule50 = ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule51 = ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])

rule52 = ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule53 = ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule54= ctrl.Rule(fever['Mild']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule55 = ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule56= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule57= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])

rule58= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule59= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule60= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])

rule61= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule62= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule63= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule64= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule65= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule66= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])

rule67= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule68= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule69= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])

rule70= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule71= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule72= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])

rule73= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule74= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule75= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])

rule76= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule77= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule78= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])

rule79= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule80= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule81= ctrl.Rule(fever['Mild']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule82= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule83= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule84= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])

rule85= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule86= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule87= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])

rule88= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule89= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule90 = ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule91= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule92= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule93= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])

rule94= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule95= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule96= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])

rule97= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule98= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule99= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])

rule100= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule101= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule102= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])

rule103= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule104= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule105= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])

rule106= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule107 = ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule108= ctrl.Rule(fever['Moderate']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule109 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule110 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule111 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])

rule112 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule113 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule114 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])

rule115 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule116 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule117 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule118 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule119 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule120 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])

rule121 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule122 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule123 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])

rule124 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule125 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule126 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])

rule127 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule128 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule129 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])

rule130 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule131 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule132 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])

rule133 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule134 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule135 = ctrl.Rule(fever['Moderate']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule136 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule137 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])
rule138 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Moderate'])

rule139 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule140 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])
rule141 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Moderate'])

rule142 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule143 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule144 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Moderate'])
rule145 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule146 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])
rule147 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Moderate'])

rule148 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule149 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])
rule150 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Moderate'])

rule151 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule152 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])
rule153 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Moderate'])

rule154 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule155 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])
rule156 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Moderate'])

rule157 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule158 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])
rule159 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Moderate'])

rule160 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule161 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])
rule162 = ctrl.Rule(fever['Moderate']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Moderate'])

rule163 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule164 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule165 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Mild'],out1['Severe'])

rule166 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule167 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule168 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])

rule169 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule170 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule171 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule172 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule173 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule174 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])

rule175 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule176 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule177 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])

rule178 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule179 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule180 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])

rule181 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule182 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule183 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Mild'],out1['Severe'])

rule184 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule185 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule186 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])

rule187 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule188 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule189 = ctrl.Rule(fever['Severe']&headache['Mild']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule190 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule191 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule192 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Mild'],out1['Severe'])

rule193 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule194 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule195 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])

rule196 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule197 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule198 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule199 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule200 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule201 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])

rule202= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule203= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule204= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])

rule205= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule206= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule207= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])

rule208= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule209= ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule210 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Mild'],out1['Severe'])

rule211 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule212 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule213 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])

rule214 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule215 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule216 = ctrl.Rule(fever['Severe']&headache['Moderate']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule217 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule218 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Severe'])
rule219= ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Mild'],out1['Severe'])

rule220 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule221 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])
rule222 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Moderate'],out1['Severe'])

rule223 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule224 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule225 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Mild']&vomiting['Severe'],out1['Severe'])
rule226 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule227 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])
rule228 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Mild'],out1['Severe'])

rule229 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule230 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])
rule231 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Moderate'],out1['Severe'])

rule232 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule233 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])
rule234 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Moderate']&vomiting['Severe'],out1['Severe'])

rule235 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule236 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Severe'])
rule237 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Mild'],out1['Severe'])

rule238 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule239 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])
rule240 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Moderate'],out1['Severe'])

rule241 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule242 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Severe'])
rule243 = ctrl.Rule(fever['Severe']&headache['Severe']&nausea['Severe']&vomiting['Severe'],out1['Severe'])

# %% [markdown]
# # **Part 2 - Rules 2**

# %%
rule1_1 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])
rule1_2 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])
rule1_3 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])

rule1_4 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])
rule1_5 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])
rule1_6 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])

rule1_7 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
rule1_8 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
rule1_9 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
   
rule1_10 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])
rule1_11 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])
rule1_12 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])

rule1_13 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Mild'])
rule1_14 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Mild'])
rule1_15 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Mild'])

rule1_16 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Mild'])
rule1_17 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Mild'])
rule1_18 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Mild'])

   
rule1_19 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Mild'])
rule1_20= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Mild'])
rule1_21 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Mild'])

rule1_22 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Mild'])
rule1_23= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Mild'])
rule1_24= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Mild'])

rule1_25= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Mild'])
rule1_26= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Mild'])
rule1_27= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Mild'])
                          
                     
rule1_28= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])
rule1_29= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])
rule1_30= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Mild'])

rule1_31= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])
rule1_32= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])
rule1_33= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Mild'])

rule1_34= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
rule1_35= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
rule1_36= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Mild'])
   
rule1_37= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])
rule1_38= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])
rule1_39= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Mild'])

rule1_40= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_41= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_42= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])

rule1_43= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_44= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_45= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])

   
rule1_46= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_47= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_48= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])

rule1_49 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_50 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_51 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])

rule1_52 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_53 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_54= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
                
       
rule1_55 = ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_56= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_57= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])

rule1_58= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_59= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_60= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])

rule1_61= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_62= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_63= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
   
rule1_64= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_65= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_66= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])

rule1_67= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_68= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_69= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])

rule1_70= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_71= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_72= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])

   
rule1_73= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_74= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_75= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])

rule1_76= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_77= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_78= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])

rule1_79= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_80= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_81= ctrl.Rule(ijaundice['Mild']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
                  
                          
                               
rule1_82= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_83= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_84= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])

rule1_85= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_86= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_87= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])

rule1_88= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_89= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_90 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
   
rule1_91= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_92= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_93= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])

rule1_94= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_95= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_96= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])

rule1_97= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_98= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_99= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])

   
rule1_100= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_101= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_102= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])

rule1_103= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_104= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_105= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])

rule1_106= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_107 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_108= ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
                          
                     
rule1_109 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_110 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_111 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])

rule1_112 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_113 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_114 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])

rule1_115 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_116 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_117 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
   
rule1_118 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_119 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_120 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])

rule1_121 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_122 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_123 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])

rule1_124 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_125 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_126 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])

   
rule1_127 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_128 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_129 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])

rule1_130 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_131 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_132 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])

rule1_133 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_134 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_135 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
                
       
rule1_136 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_137 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])
rule1_138 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Moderate'])

rule1_139 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_140 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])
rule1_141 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Moderate'])

rule1_142 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_143 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
rule1_144 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Moderate'])
   
rule1_145 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_146 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])
rule1_147 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Moderate'])

rule1_148 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_149 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])
rule1_150 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Moderate'])

rule1_151 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_152 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])
rule1_153 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Moderate'])

   
rule1_154 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_155 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])
rule1_156 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Moderate'])

rule1_157 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_158 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])
rule1_159 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Moderate'])

rule1_160 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_161 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])
rule1_162 = ctrl.Rule(ijaundice['Moderate']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Moderate'])

                       
                       
                        
rule1_163 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_164 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_165 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])

rule1_166 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_167 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_168 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])

rule1_169 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_170 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_171 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
   
rule1_172 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_173 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_174 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])

rule1_175 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_176 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_177 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])

rule1_178 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_179 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_180 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])

   
rule1_181 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_182 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_183 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])

rule1_184 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_185 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_186 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])

rule1_187 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_188 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_189 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Mild']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
                          
                     
rule1_190 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_191 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_192 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])

rule1_193 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_194 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_195 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])

rule1_196 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_197 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_198 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
   
rule1_199 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_200 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_201 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])

rule1_202= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_203= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_204= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])

rule1_205= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_206= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_207= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])

   
rule1_208= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_209= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_210 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])

rule1_211 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_212 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_213 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])

rule1_214 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_215 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_216 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Moderate']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
                
       
rule1_217 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_218 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])
rule1_219= ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Mild'],out2['Severe'])

rule1_220 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_221 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])
rule1_222 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Moderate'],out2['Severe'])

rule1_223 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_224 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
rule1_225 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Mild']&body_weakness['Severe'],out2['Severe'])
   
rule1_226 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_227 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])
rule1_228 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Mild'],out2['Severe'])

rule1_229 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_230 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])
rule1_231 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Moderate'],out2['Severe'])

rule1_232 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_233 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])
rule1_234 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Moderate']&body_weakness['Severe'],out2['Severe'])

   
rule1_235 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_236 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])
rule1_237 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Mild'],out2['Severe'])

rule1_238 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_239 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])
rule1_240 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Moderate'],out2['Severe'])

rule1_241 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_242 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])
rule1_243 = ctrl.Rule(ijaundice['Severe']&enlarge_liver['Severe']&joint_pain['Severe']&body_weakness['Severe'],out2['Severe'])

# %% [markdown]
# # **Part 2 - Rules 3**

# %%
rule2_1 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])
rule2_2 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])
rule2_3 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])

rule2_4 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Moderate'],out3['Mild'])
rule2_5 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Moderate'],out3['Mild'])
rule2_6 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Moderate'],out3['Mild'])

rule2_7 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Severe'],out3['Mild'])
rule2_8 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Severe'],out3['Mild'])
rule2_9 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Mild']&mp['Severe'],out3['Mild'])
   
rule2_10 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Mild'],out3['Mild'])
rule2_11 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Mild'],out3['Mild'])
rule2_12 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Mild'],out3['Mild'])

rule2_13 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Mild'])
rule2_14 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Mild'])
rule2_15 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Mild'])

rule2_16 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Severe'],out3['Mild'])
rule2_17 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Severe'],out3['Mild'])
rule2_18 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Moderate']&mp['Severe'],out3['Mild'])

   
rule2_19 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Mild'],out3['Mild'])
rule2_20= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Mild'],out3['Mild'])
rule2_21 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Mild'],out3['Mild'])

rule2_22 = ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Moderate'],out3['Mild'])
rule2_23= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Moderate'],out3['Mild'])
rule2_24= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Moderate'],out3['Mild'])

rule2_25= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Severe'],out3['Mild'])
rule2_26= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Severe'],out3['Mild'])
rule2_27= ctrl.Rule(dizziness['Mild']&loss_of_appetite['Severe']&mp['Severe'],out3['Mild'])
                          
                     
rule2_28= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])
rule2_29= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])
rule2_30= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Mild'],out3['Mild'])

rule2_31= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Moderate'],out3['Moderate'])
rule2_32= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Moderate'],out3['Moderate'])
rule2_33= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Moderate'],out3['Moderate'])

rule2_34= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Severe'],out3['Moderate'])
rule2_35= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Severe'],out3['Moderate'])
rule2_36= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Mild']&mp['Severe'],out3['Moderate'])
   
rule2_37= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Mild'],out3['Moderate'])
rule2_38= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Mild'],out3['Moderate'])
rule2_39= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Mild'],out3['Moderate'])

rule2_40= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Moderate'])
rule2_41= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Moderate'])
rule2_42= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Moderate'])

rule2_43= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Severe'],out3['Moderate'])
rule2_44= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Severe'],out3['Moderate'])
rule2_45= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Moderate']&mp['Severe'],out3['Moderate'])

   
rule2_46= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Mild'],out3['Moderate'])
rule2_47= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Mild'],out3['Moderate'])
rule2_48= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Mild'],out3['Moderate'])

rule2_49 = ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Moderate'],out3['Moderate'])
rule2_50 = ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Moderate'],out3['Moderate'])
rule2_51 = ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Moderate'],out3['Moderate'])

rule2_52 = ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Severe'],out3['Moderate'])
rule2_53 = ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Severe'],out3['Moderate'])
rule2_54= ctrl.Rule(dizziness['Moderate']&loss_of_appetite['Severe']&mp['Severe'],out3['Moderate'])
                
       
rule2_55 = ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Mild'],out3['Severe'])
rule2_56= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Mild'],out3['Severe'])
rule2_57= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Mild'],out3['Severe'])

rule2_58= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Moderate'],out3['Severe'])
rule2_59= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Moderate'],out3['Severe'])
rule2_60= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Moderate'],out3['Severe'])

rule2_61= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Severe'],out3['Severe'])
rule2_62= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Severe'],out3['Severe'])
rule2_63= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Mild']&mp['Severe'],out3['Severe'])
   
rule2_64= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Mild'],out3['Severe'])
rule2_65= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Mild'],out3['Severe'])
rule2_66= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Mild'],out3['Severe'])

rule2_67= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Severe'])
rule2_68= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Severe'])
rule2_69= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Moderate'],out3['Severe'])

rule2_70= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Severe'],out3['Severe'])
rule2_71= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Severe'],out3['Severe'])
rule2_72= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Moderate']&mp['Severe'],out3['Severe'])

   
rule2_73= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Mild'],out3['Severe'])
rule2_74= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Mild'],out3['Severe'])
rule2_75= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Mild'],out3['Severe'])

rule2_76= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Moderate'],out3['Severe'])
rule2_77= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Moderate'],out3['Severe'])
rule2_78= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Moderate'],out3['Severe'])

rule2_79= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Severe'],out3['Severe'])
rule2_80= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Severe'],out3['Severe'])
rule2_81= ctrl.Rule(dizziness['Severe']&loss_of_appetite['Severe']&mp['Severe'],out3['Severe'])

# %%
rule3_1 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Mild'],conclu['Mild'])
rule3_2 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Mild'],conclu['Mild'])
rule3_3 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Mild'],conclu['Mild'])

rule3_4 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Moderate'],conclu['Mild'])
rule3_5 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Moderate'],conclu['Mild'])
rule3_6 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Moderate'],conclu['Mild'])

rule3_7 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Severe'],conclu['Mild'])
rule3_8 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Severe'],conclu['Mild'])
rule3_9 = ctrl.Rule(out1['Mild']&out2['Mild']&out3['Severe'],conclu['Mild'])
rule3_10 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Mild'],conclu['Mild'])
rule3_11 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Mild'],conclu['Mild'])
rule3_12 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Mild'],conclu['Mild'])

rule3_13 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Moderate'],conclu['Mild'])
rule3_14 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Moderate'],conclu['Mild'])
rule3_15 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Moderate'],conclu['Mild'])

rule3_16 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Severe'],conclu['Mild'])
rule3_17 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Severe'],conclu['Mild'])
rule3_18 = ctrl.Rule(out1['Mild']&out2['Moderate']&out3['Severe'],conclu['Mild'])

rule3_19 = ctrl.Rule(out1['Mild']&out2['Severe']&out3['Mild'],conclu['Mild'])
rule3_20= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Mild'],conclu['Mild'])
rule3_21 = ctrl.Rule(out1['Mild']&out2['Severe']&out3['Mild'],conclu['Mild'])

rule3_22 = ctrl.Rule(out1['Mild']&out2['Severe']&out3['Moderate'],conclu['Mild'])
rule3_23= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Moderate'],conclu['Mild'])
rule3_24= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Moderate'],conclu['Mild'])

rule3_25= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Severe'],conclu['Mild'])
rule3_26= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Severe'],conclu['Mild'])
rule3_27= ctrl.Rule(out1['Mild']&out2['Severe']&out3['Severe'],conclu['Mild'])
rule3_28= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Mild'],conclu['Mild'])
rule3_29= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Mild'],conclu['Mild'])
rule3_30= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Mild'],conclu['Mild'])

rule3_31= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Moderate'],conclu['Moderate'])
rule3_32= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Moderate'],conclu['Moderate'])
rule3_33= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Moderate'],conclu['Moderate'])

rule3_34= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Severe'],conclu['Moderate'])
rule3_35= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Severe'],conclu['Moderate'])
rule3_36= ctrl.Rule(out1['Moderate']&out2['Mild']&out3['Severe'],conclu['Moderate'])
rule3_37= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Mild'],conclu['Moderate'])
rule3_38= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Mild'],conclu['Moderate'])
rule3_39= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Mild'],conclu['Moderate'])

rule3_40= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Moderate'],conclu['Moderate'])
rule3_41= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Moderate'],conclu['Moderate'])
rule3_42= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Moderate'],conclu['Moderate'])

rule3_43= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Severe'],conclu['Moderate'])
rule3_44= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Severe'],conclu['Moderate'])
rule3_45= ctrl.Rule(out1['Moderate']&out2['Moderate']&out3['Severe'],conclu['Moderate'])

rule3_46= ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Mild'],conclu['Moderate'])
rule3_47= ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Mild'],conclu['Moderate'])
rule3_48= ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Mild'],conclu['Moderate'])

rule3_49 = ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Moderate'],conclu['Moderate'])
rule3_50 = ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Moderate'],conclu['Moderate'])
rule3_51 = ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Moderate'],conclu['Moderate'])

rule3_52 = ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Severe'],conclu['Moderate'])
rule3_53 = ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Severe'],conclu['Moderate'])
rule3_54= ctrl.Rule(out1['Moderate']&out2['Severe']&out3['Severe'],conclu['Moderate'])
rule3_55 = ctrl.Rule(out1['Severe']&out2['Mild']&out3['Mild'],conclu['Severe'])
rule3_56= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Mild'],conclu['Severe'])
rule3_57= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Mild'],conclu['Severe'])

rule3_58= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Moderate'],conclu['Severe'])
rule3_59= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Moderate'],conclu['Severe'])
rule3_60= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Moderate'],conclu['Severe'])

rule3_61= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Severe'],conclu['Severe'])
rule3_62= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Severe'],conclu['Severe'])
rule3_63= ctrl.Rule(out1['Severe']&out2['Mild']&out3['Severe'],conclu['Severe'])
rule3_64= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Mild'],conclu['Severe'])
rule3_65= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Mild'],conclu['Severe'])
rule3_66= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Mild'],conclu['Severe'])

rule3_67= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Moderate'],conclu['Severe'])
rule3_68= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Moderate'],conclu['Severe'])
rule3_69= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Moderate'],conclu['Severe'])

rule3_70= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Severe'],conclu['Severe'])
rule3_71= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Severe'],conclu['Severe'])
rule3_72= ctrl.Rule(out1['Severe']&out2['Moderate']&out3['Severe'],conclu['Severe'])

rule3_73= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Mild'],conclu['Severe'])
rule3_74= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Mild'],conclu['Severe'])
rule3_75= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Mild'],conclu['Severe'])

rule3_76= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Moderate'],conclu['Severe'])
rule3_77= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Moderate'],conclu['Severe'])
rule3_78= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Moderate'],conclu['Severe'])

rule3_79= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Severe'],conclu['Severe'])
rule3_80= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Severe'],conclu['Severe'])
rule3_81= ctrl.Rule(out1['Severe']&out2['Severe']&out3['Severe'],conclu['Severe'])

# %%
concluing_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25, rule26, rule27, rule28, rule29, rule30, rule31, rule32, rule33, rule34, rule35, rule36, rule37, rule38, rule39, rule40, rule41, rule42, rule43, rule44, rule45, rule46, rule47, rule48, rule49, rule50, rule51, rule52, rule53, rule54, rule55, rule56, rule57, rule58, rule59, rule60, rule61, rule62, rule63, rule64, rule65, rule66, rule67, rule68, rule69, rule70, rule71, rule72, rule73, rule74, rule75, rule76, rule77, rule78, rule79, rule80, rule81, rule82, rule83, rule84, rule85, rule86, rule87, rule88, rule89, rule90, rule91, rule92, rule93, rule94, rule95, rule96, rule97, rule98, rule99, rule100, rule101, rule102, rule103, rule104, rule105, rule106, rule107, rule108, rule109, rule110, rule111, rule112, rule113, rule114, rule115, rule116, rule117, rule118, rule119, rule120, rule121, rule122, rule123, rule124, rule125, rule126, rule127, rule128, rule129, rule130, rule131, rule132, rule133, rule134, rule135, rule136, rule137, rule138, rule139, rule140, rule141, rule142, rule143, rule144, rule145, rule146, rule147, rule148, rule149, rule150, rule151, rule152, rule153, rule154, rule155, rule156, rule157, rule158, rule159, rule160, rule161, rule162, rule163, rule164, rule165, rule166, rule167, rule168, rule169, rule170, rule171, rule172, rule173, rule174, rule175, rule176, rule177, rule178, rule179, rule180, rule181, rule182, rule183, rule184, rule185, rule186, rule187, rule188, rule189, rule190, rule191, rule192, rule193, rule194, rule195, rule196, rule197, rule198, rule199, rule200, rule201, rule202, rule203, rule204, rule205, rule206, rule207, rule208, rule209, rule210, rule211, rule212, rule213, rule214, rule215, rule216, rule217, rule218, rule219, rule220, rule221, rule222, rule223, rule224, rule225, rule226, rule227, rule228, rule229, rule230, rule231, rule232, rule233, rule234, rule235, rule236, rule237, rule238, rule239, rule240, rule241, rule242, rule243,rule1_1, rule1_2, rule1_3, rule1_4, rule1_5, rule1_6, rule1_7, rule1_8, rule1_9, rule1_10, rule1_11, rule1_12, rule1_13, rule1_14, rule1_15, rule1_16, rule1_17, rule1_18, rule1_19, rule1_20, rule1_21, rule1_22, rule1_23, rule1_24, rule1_25, rule1_26, rule1_27, rule1_28, rule1_29, rule1_30, rule1_31, rule1_32, rule1_33, rule1_34, rule1_35, rule1_36, rule1_37, rule1_38, rule1_39, rule1_40, rule1_41, rule1_42, rule1_43, rule1_44, rule1_45, rule1_46, rule1_47, rule1_48, rule1_49, rule1_50, rule1_51, rule1_52, rule1_53, rule1_54, rule1_55, rule1_56, rule1_57, rule1_58, rule1_59, rule1_60, rule1_61, rule1_62, rule1_63, rule1_64, rule1_65, rule1_66, rule1_67, rule1_68, rule1_69, rule1_70, rule1_71, rule1_72, rule1_73, rule1_74, rule1_75, rule1_76, rule1_77, rule1_78, rule1_79, rule1_80, rule1_81, rule1_82, rule1_83, rule1_84, rule1_85, rule1_86, rule1_87, rule1_88, rule1_89, rule1_90, rule1_91, rule1_92, rule1_93, rule1_94, rule1_95, rule1_96, rule1_97, rule1_98, rule1_99, rule1_100, rule1_101, rule1_102, rule1_103, rule1_104, rule1_105, rule1_106, rule1_107, rule1_108, rule1_109, rule1_110, rule1_111, rule1_112, rule1_113, rule1_114, rule1_115, rule1_116, rule1_117, rule1_118, rule1_119, rule1_120, rule1_121, rule1_122, rule1_123, rule1_124, rule1_125, rule1_126, rule1_127, rule1_128, rule1_129, rule1_130, rule1_131, rule1_132, rule1_133, rule1_134, rule1_135, rule1_136, rule1_137, rule1_138, rule1_139, rule1_140, rule1_141, rule1_142, rule1_143, rule1_144, rule1_145, rule1_146, rule1_147, rule1_148, rule1_149, rule1_150, rule1_151, rule1_152, rule1_153, rule1_154, rule1_155, rule1_156, rule1_157, rule1_158, rule1_159, rule1_160, rule1_161, rule1_162, rule1_163, rule1_164, rule1_165, rule1_166, rule1_167, rule1_168, rule1_169, rule1_170, rule1_171, rule1_172, rule1_173, rule1_174, rule1_175, rule1_176, rule1_177, rule1_178, rule1_179, rule1_180, rule1_181, rule1_182, rule1_183, rule1_184, rule1_185, rule1_186, rule1_187, rule1_188, rule1_189, rule1_190, rule1_191, rule1_192, rule1_193, rule1_194, rule1_195, rule1_196, rule1_197, rule1_198, rule1_199, rule1_200, rule1_201, rule1_202, rule1_203, rule1_204, rule1_205, rule1_206, rule1_207, rule1_208, rule1_209, rule1_210, rule1_211, rule1_212, rule1_213, rule1_214, rule1_215, rule1_216, rule1_217, rule1_218, rule1_219, rule1_220, rule1_221, rule1_222, rule1_223, rule1_224, rule1_225, rule1_226, rule1_227, rule1_228, rule1_229, rule1_230, rule1_231, rule1_232, rule1_233, rule1_234, rule1_235, rule1_236, rule1_237, rule1_238, rule1_239, rule1_240, rule1_241, rule1_242, rule1_243, rule2_1, rule2_2, rule2_3, rule2_4, rule2_5, rule2_6, rule2_7, rule2_8, rule2_9, rule2_10, rule2_11, rule2_12, rule2_13, rule2_14, rule2_15, rule2_16, rule2_17, rule2_18, rule2_19, rule2_20, rule2_21, rule2_22, rule2_23, rule2_24, rule2_25, rule2_26, rule2_27, rule2_28, rule2_29, rule2_30, rule2_31, rule2_32, rule2_33, rule2_34, rule2_35, rule2_36, rule2_37, rule2_38, rule2_39, rule2_40, rule2_41, rule2_42, rule2_43, rule2_44, rule2_45, rule2_46, rule2_47, rule2_48, rule2_49, rule2_50, rule2_51, rule2_52, rule2_53, rule2_54, rule2_55, rule2_56, rule2_57, rule2_58, rule2_59, rule2_60, rule2_61, rule2_62, rule2_63, rule2_64, rule2_65, rule2_66, rule2_67, rule2_68, rule2_69, rule2_70, rule2_71, rule2_72, rule2_73, rule2_74, rule2_75, rule2_76, rule2_77, rule2_78, rule2_79, rule2_80, rule2_81,rule3_1, rule3_2, rule3_3, rule3_4, rule3_5, rule3_6, rule3_7, rule3_8, rule3_9, rule3_10, rule3_11, rule3_12, rule3_13, rule3_14, rule3_15, rule3_16, rule3_17, rule3_18, rule3_19, rule3_20, rule3_21, rule3_22, rule3_23, rule3_24, rule3_25, rule3_26, rule3_27, rule3_28, rule3_29, rule3_30, rule3_31, rule3_32, rule3_33, rule3_34, rule3_35, rule3_36, rule3_37, rule3_38, rule3_39, rule3_40, rule3_41, rule3_42, rule3_43, rule3_44, rule3_45, rule3_46, rule3_47, rule3_48, rule3_49, rule3_50, rule3_51, rule3_52, rule3_53, rule3_54, rule3_55, rule3_56, rule3_57, rule3_58, rule3_59, rule3_60, rule3_61, rule3_62, rule3_63, rule3_64, rule3_65, rule3_66, rule3_67, rule3_68, rule3_69, rule3_70, rule3_71, rule3_72, rule3_73, rule3_74, rule3_75, rule3_76, rule3_77, rule3_78, rule3_79, rule3_80, rule3_81 ])
concluing = ctrl.ControlSystemSimulation(concluing_ctrl)
concluing.input['Fever'] = 0.5
concluing.input['Headache'] = 0.6
concluing.input['Nausea'] = 0.4
concluing.input['Vomiting'] = 0.5
concluing.input['Ijaundice'] = 0.4
concluing.input['Enlarge_liver'] = 0.3
concluing.input['Joint_pain'] = 0.7
concluing.input['Body_weakness'] = 0.5
concluing.input['Dizziness'] = 0.6
concluing.input['Loss_of_appetite'] = 0.5
concluing.input['Mp'] = 0.6
concluing.compute()
print(concluing.output['Conclu'])
conclu.view(sim=concluing)
# Out:
# 0.1999999999999999

# %%
# for i in range(81):
#   print("rule3_{0},".format(i+1))
