# %% [markdown]
# # **Fashion MNIST**

# %%
import numpy as np

# %%
from matplotlib import pyplot
from keras.datasets import fashion_mnist
data = fashion_mnist.load_data()

# %%
(X_train, y_train),(X_test,y_test) = data

# %%
print("x train: ", X_train.shape)
print("x  test: ", X_test.shape)
print("y train: ", y_train.shape)
print("y test: ", y_test.shape)
# Out:
# x train:  (60000, 28, 28)
# x  test:  (10000, 28, 28)
# y train:  (60000,)
# y test:  (10000,)

# %%
# # reshape
# X = X_train
# y = y_train

# X_train = X_train.reshape(60000,28*28*1)
# X_train = X_train.astype('float32')/255
# X_test = X_test.reshape(10000,28*28*1)
# X_test = X_test.astype('float32')/255

# X_train.shape
# Out:
# (60000, 784)

# %%
# one hot encoding - (chay 1 lan duy nhat)
from keras.utils import to_categorical
# y_test = to_categorical(y_test,10)

y_train = to_categorical(y_train,10)  #1 to 10 bits
y_test = to_categorical(y_test,10)
y_train.shape
y_test.shape
# Out:
# (10000, 10)

# %% [markdown]
# # **Convolution NN**

# %%
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Normalization, LeakyReLU
from keras.optimizers import Adam

# %%
model = Sequential()
#1

model.add(Conv2D(filters=32,kernel_size=(3,3),activation='linear',
                 input_shape=(28,28,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
#2

model.add(Conv2D(filters=64,kernel_size=(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
#3

model.add(Conv2D(filters=128,kernel_size=(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2,2),padding='same'))

# %% [markdown]
# # **ANN**

# %%
model.add(Flatten())
# model.add(Dense(filters=64, activation='relu'))
model.add(Dense(units=128,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(10,activation='softmax'))

from keras.losses import categorical_crossentropy
model.compile(optimizer=Adam(),loss=categorical_crossentropy,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        320
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 64)        18496
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 128)         73856
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# ...

# %%
train = model.fit(X_train,y_train,batch_size=64,epochs=20,verbose=1)
# Out:
# Epoch 1/20
# 938/938 [==============================] - 13s 5ms/step - loss: 0.6470 - accuracy: 0.8415
# Epoch 2/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2836 - accuracy: 0.8978
# Epoch 3/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2432 - accuracy: 0.9100
# Epoch 4/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.2161 - accuracy: 0.9202
# Epoch 5/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2011 - accuracy: 0.9253
# Epoch 6/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1898 - accuracy: 0.9307
# Epoch 7/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.1727 - accuracy: 0.9357
# Epoch 8/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1671 - accuracy: 0.9381
# Epoch 9/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1536 - accuracy: 0.9433
# Epoch 10/20
# ...

# %%
import pickle

filename = '/content/drive/MyDrive/A_HOC TAP/Nam 4, Hoc ky 2/Artificial Intelligence/Code_AI/files/week11_CNN_ANN.h5'
pickle.dump(model, open(filename, 'wb'))

# %%
# loaded_model = pickle.load(open(filename, 'rb'))
# result = loaded_model.score(X_test, y_test)
# print(result)

# %%
model.save('/content/drive/MyDrive/A_HOC TAP/Nam 4, Hoc ky 2/Artificial Intelligence/Code_AI/files/week11_CNN.h5')

# %%
from keras import models    
model = models.load_model('/content/drive/MyDrive/A_HOC TAP/Nam 4, Hoc ky 2/Artificial Intelligence/Code_AI/files/week11_CNN.h5')
